# %% [markdown]
# # Cohort Retention Analysis
# This notebook focuses on analyzing customer retention over time using cohort analysis. We will categorize customers based on their first purchase month and track their subsequent purchases.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style('white')
plt.rcParams['figure.figsize'] = (16, 10)

# %% [markdown]
# ## 1. Data Loading
# Assuming data is exported from SQL Server after order grain consolidation.

# %%
# Load analytical orders dataset (mocking the structure for demonstration)
# df = pd.read_csv('analytical_orders.csv')

# Example structure based on our SQL output:
# df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
# df['customer_unique_id'] = df['customer_unique_id'].astype(str)
# df['payment_value'] = df['payment_value'].astype(float)

# %% [markdown]
# ## 2. Cohort Assignment
# Assign each customer to a cohort based on their first purchase month.

# %%
def extract_month(x):
    return pd.datetime(x.year, x.month, 1)

# df['order_month'] = df['order_purchase_timestamp'].apply(extract_month)
# df['cohort_month'] = df.groupby('customer_unique_id')['order_month'].transform('min')

# %% [markdown]
# ## 3. Calculate Cohort Index
# Calculate the number of months between a purchase and the customer's first purchase.

# %%
def get_date_int(df, column):
    year = df[column].dt.year
    month = df[column].dt.month
    return year, month

# order_year, order_month = get_date_int(df, 'order_month')
# cohort_year, cohort_month = get_date_int(df, 'cohort_month')

# years_diff = order_year - cohort_year
# months_diff = order_month - cohort_month

# df['cohort_index'] = years_diff * 12 + months_diff

# %% [markdown]
# ## 4. Cohort Retention Matrix
# Pivot the data to calculate the percentage of customers returning in subsequent months.

# %%
# cohort_data = df.groupby(['cohort_month', 'cohort_index'])['customer_unique_id'].apply(pd.Series.nunique).reset_index()
# cohort_counts = cohort_data.pivot(index='cohort_month', columns='cohort_index', values='customer_unique_id')

# cohort_sizes = cohort_counts.iloc[:,0]
# retention = cohort_counts.divide(cohort_sizes, axis=0)

# retention.index = retention.index.strftime('%Y-%m')

# %% [markdown]
# ## 5. Retention Heatmap Visualization

# %%
# plt.figure(figsize=(20, 14))
# plt.title('Cohort Retention Matrix', fontsize=20)
# sns.heatmap(retention, annot=True, fmt='.1%', cmap='YlGnBu', vmin=0.0, vmax=0.1)
# plt.ylabel('Cohort Month', fontsize=14)
# plt.xlabel('Cohort Index (Months since first purchase)', fontsize=14)
# plt.show()
